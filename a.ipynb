# %%
import csv

with open('GPUv7.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'\tcard:{row[0]} ,power: {row[1]} rank: {row[2]}.')
            line_count += 1
    print(f'Processed {line_count} lines.')
# Out:
# Column names are ן»¿gpuName, G3Dmark, G2Dmark, price, gpuValue, TDP, powerPerformance, testDate, category
# 	card:GeForce RTX 3090 Ti ,power: 29094 rank: 1117.
# 	card:GeForce RTX 3080 Ti ,power: 26887 rank: 1031.
# 	card:GeForce RTX 3090 ,power: 26395 rank: 999.
# 	card:Radeon RX 6900 XT ,power: 25458 rank: 1102.
# 	card:GeForce RTX 3080 ,power: 24853 rank: 1003.
# 	card:GeForce RTX 3070 Ti ,power: 23367 rank: 1003.
# 	card:Radeon RX 6800 XT ,power: 23364 rank: 1078.
# 	card:RTX A5000 ,power: 22867 rank: 984.
# 	card:RTX A6000 ,power: 22122 rank: 832.
# 	card:GeForce RTX 3070 ,power: 22093 rank: 969.
# 	card:GeForce RTX 2080 Ti ,power: 21796 rank: 940.
# 	card:RTX A4500 ,power: 21546 rank: 892.
# 	card:Radeon RX 6800 ,power: 20667 rank: 1030.
# 	card:GeForce RTX 3060 Ti ,power: 20206 rank: 961.
# 	card:TITAN RTX ,power: 20169 rank: 844.
# 	card:Quadro RTX 6000 ,power: 19692 rank: 837.
# 	card:GeForce RTX 2080 SUPER ,power: 19519 rank: 934.
# 	card:TITAN Xp ,power: 19508 rank: 992.
# ...

# %%
import csv
lst=[]
with open('cards.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            try:
                print(f'\tcard:{row[0]} ,power: {row[1]} rank: {row[1]}.')
                line_count += 1
                lst.append([row[0],row[1]])
            except:
                print(row)
                pass
    print(f'Processed {line_count} lines.')
print("len="+str(len(lst)))
# Out:
# Column names are Videocard,  3D Rating,  Rank,  2D Rating,  Samples,  First Seen in Charts,  Memory Size,  Core Clock,  Mem Clock,  Category
# 	card:Radeon RX 6900 XT ,power: 25521 rank: 25521.
# 	card:GeForce RTX 3090 ,power: 25283 rank: 25283.
# 	card:GeForce RTX 3080 ,power: 23957 rank: 23957.
# 	card:Radeon RX 6800 XT ,power: 23707 rank: 23707.
# 	card:GeForce RTX 3070 ,power: 21447 rank: 21447.
# 	card:RX6800 XT ,power: 21408 rank: 21408.
# 	card:GeForce RTX 2080 Ti ,power: 21240 rank: 21240.
# 	card:RTX A6000 ,power: 21075 rank: 21075.
# 	card:Radeon RX 6800 ,power: 20844 rank: 20844.
# 	card:Quadro RTX 8000 ,power: 20595 rank: 20595.
# 	card:TITAN V ,power: 20153 rank: 20153.
# 	card:TITAN RTX ,power: 19849 rank: 19849.
# 	card:GeForce RTX 3060 Ti ,power: 19516 rank: 19516.
# 	card:Quadro RTX 6000 ,power: 19394 rank: 19394.
# 	card:GeForce RTX 2080 SUPER ,power: 19207 rank: 19207.
# 	card:Radeon RX 6700 XT ,power: 18517 rank: 18517.
# ...

# %%
lst=[]
with open('cards.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            print(f'Column names are {", ".join(row)}')
            line_count += 1
        else:
            print(f'\tcard:{row[0]} ,power: {row[1]} rank: {row[2]}.')
            line_count += 1
            lst.append([row[0],row[1]])
    print(f'Processed {line_count} lines.')
print("len:"+len(lst))
# Out:
# Column names are Videocard,  3D Rating,  Rank,  2D Rating,  Samples,  First Seen in Charts,  Memory Size,  Core Clock,  Mem Clock,  Category
# 	card:Radeon RX 6900 XT ,power: 25521 rank: 1.
# 	card:GeForce RTX 3090 ,power: 25283 rank: 2.
# 	card:GeForce RTX 3080 ,power: 23957 rank: 3.
# 	card:Radeon RX 6800 XT ,power: 23707 rank: 4.
# 	card:GeForce RTX 3070 ,power: 21447 rank: 5.
# 	card:RX6800 XT ,power: 21408 rank: 6.
# 	card:GeForce RTX 2080 Ti ,power: 21240 rank: 7.
# 	card:RTX A6000 ,power: 21075 rank: 8.
# 	card:Radeon RX 6800 ,power: 20844 rank: 9.
# 	card:Quadro RTX 8000 ,power: 20595 rank: 10.
# 	card:TITAN V ,power: 20153 rank: 11.
# 	card:TITAN RTX ,power: 19849 rank: 12.
# 	card:GeForce RTX 3060 Ti ,power: 19516 rank: 13.
# 	card:Quadro RTX 6000 ,power: 19394 rank: 14.
# 	card:GeForce RTX 2080 SUPER ,power: 19207 rank: 15.
# 	card:Radeon RX 6700 XT ,power: 18517 rank: 16.
# 	card:GeForce RTX 2080 ,power: 18396 rank: 17.
# 	card:NVIDIA TITAN Xp ,power: 18280 rank: 18.
# ...
